# %%
import pandas as pd

data = pd.read_csv('../data/Financials Sample Data.csv')
print(data.head())
# Out:
#                           Account Businees Unit Currency  Year Scenario  \
# 0                           Sales      Software      USD  2012  Actuals
# 1              Cost of Goods Sold      Software      USD  2012  Actuals
# 2             Commissions Expense      Software      USD  2012  Actuals
# 3                 Payroll Expense      Software      USD  2012  Actuals
# 4  Travel & Entertainment Expense      Software      USD  2012  Actuals
#
#              Jan            Feb            Mar            Apr            May  \
# 0   $90,924,002    $82,606,134    $72,780,220    $52,943,701    $77,528,109
# 1  ($41,623,278)  ($40,464,347)  ($30,806,326)  ($21,412,962)  ($37,047,252)
# 2   ($4,454,359)   ($3,386,032)   ($3,389,705)   ($2,149,257)   ($3,168,079)
# 3   ($9,901,680)   ($9,871,172)   ($8,459,696)   ($6,303,408)   ($8,493,573)
# 4     ($951,255)     ($838,985)     ($872,700)     ($624,416)     ($919,835)
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv('../data/Financials Sample Data.csv')

# Assuming currency values are in strings and need to be converted to numerical format
data.replace('[\$,]', '', regex=True, inplace=True)
data = data.apply(pd.to_numeric, errors='coerce')

# Handling missing values - this is a simple fill with zero, consider other methods too
data.fillna(0, inplace=True)

# %%
print(data.columns)
# Out:
# Index(['Account', 'Businees Unit', 'Currency', 'Year', 'Scenario', 'Jan',
#        'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov',
#        'Dec'],
#       dtype='object')

# %%
# Define features and target
# Here we assume we're predicting December sales based on January to November
monthly_columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov']
features = data[monthly_columns]
target = data['Dec']

# %%
# Convert currency formatted strings to numbers if they aren't already
data.replace('[\$,]', '', regex=True, inplace=True)
data = data.apply(pd.to_numeric, errors='coerce')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 5811712398736.593

# %%
# !pip install seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 2.7 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Now you can plot
sns.boxplot(data=data[monthly_columns])
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(random_state=42)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
print(f'New Mean Squared Error: {mse}')
# Out:
# New Mean Squared Error: 2005732650532.1338

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Since we already calculated MSE

print(f'Root Mean Squared Error: {rmse}')
print(f'Mean Absolute Error: {mae}')
# Out:
# Root Mean Squared Error: 1416238.9101179694
# Mean Absolute Error: 414767.30028169

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Sales')
plt.show()

# %%
feature_importances = model.feature_importances_
# Create a bar chart of the feature importances
sns.barplot(x=feature_importances, y=monthly_columns)
plt.show()

# %%
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.hlines(y=0, xmin=y_pred.min(), xmax=y_pred.max(), colors='red')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
# For example, you might log-transform the target if it's heavily skewed
y_log = np.log1p(data['Dec'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# Load and prepare the data
data = pd.read_csv('../data/Financials Sample Data.csv')

# Assuming that the monthly columns are named 'Jan', 'Feb', 'Mar', ..., 'Nov'
monthly_columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct']
target_column = 'Nov'

# Convert currency formatted strings to numbers if they aren't already
data.replace('[\$,]', '', regex=True, inplace=True)
data = data.apply(pd.to_numeric, errors='coerce')

# Drop rows with missing values or impute them as necessary
data.dropna(inplace=True)

features = data[monthly_columns]
target = data[target_column]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 8
#       5 from sklearn.preprocessing import StandardScaler
#       7 # Load and prepare the data
# ----> 8 data = pd.read_csv('Financials Sample Data.csv')
#      10 # Assuming that the monthly columns are named 'Jan', 'Feb', 'Mar', ..., 'Nov'
#      11 monthly_columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct']
#
# ...
